# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimasr68/Emotion-Prediction-DNN/blob/master/Brain_fMRI_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U --user nilearn
# Out:
# Requirement already up-to-date: nilearn in /root/.local/lib/python3.7/site-packages (0.7.1)
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import nilearn
from nilearn import plotting, image
from nilearn.plotting import view_img, glass_brain, plot_anat, plot_epi
from nilearn.plotting import plot_glass_brain
import nibabel as nib

# %%
img = nib.load('/content/drive/My Drive/Colab Notebooks/fMRI/Data/activation_tvalues_3_Happiness.nii')

data1 = img.get_data()
data1.shape
# Out:
# (46, 55, 46)

# %%
base_dir2 = '/content/drive/My Drive/Colab Notebooks/fMRI/Data/'
data = nib.load(os.path.join(base_dir2, 'activation_tvalues_3_Happiness.nii'))

data.get_data()

print(data.shape)

plt.imshow(data.get_data()[:,:, 25])
# Out:
# (46, 55, 46)

# %%
plt.imshow(data.get_data()[:,:, 25], cmap='jet')

# %%
plotting.plot_stat_map(data)

# %%
plotting.plot_stat_map(data, threshold=2)

# %%
plotting.plot_stat_map(data, threshold=3)

# %%
plot_anat(data)

# %%
plot_anat(data, draw_cross=False, display_mode='z')

# %%
view_img(data)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;...&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
#   &lt;/div&gt;
#
# ...
